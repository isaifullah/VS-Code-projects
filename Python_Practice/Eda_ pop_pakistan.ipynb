# %% [markdown]
# ## Pandas Day 01

# %%
#import libraries
import pandas as pd
import numpy as np

# %%
# import data as csv
df = pd.read_csv('population_pakistan.csv')
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# ...

# %%
#write the data
df.to_excel('population_pakistan.xlsx', index=False)

# %% [markdown]
# ## pandas tips and tricks

# %%
#print the data variables or data in terminal
print(df)
# Out:
#      PROVINCE                   DIVISION                   DISTRICT  \
# 0      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 1      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 2      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 3      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 4      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# ..        ...                        ...                        ...
# 523  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 524  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 525  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 526  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 527  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
#
#             SUB DIVISION  AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# 0    BAHAWALNAGAR TEHSIL        1729.0             619550        316864
# ...

# %%
#how does the data look like
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PROVINCE                    528 non-null    object
#  1   DIVISION                    528 non-null    object
#  2   DISTRICT                    528 non-null    object
#  3   SUB DIVISION                528 non-null    object
#  4   AREA (sq.km)                528 non-null    float64
#  5   ALL SEXES (RURAL)           528 non-null    int64
#  6   MALE (RURAL)                528 non-null    int64
#  7   FEMALE (RURAL)              528 non-null    int64
#  8   TRANSGENDER (RURAL)         528 non-null    int64
#  9   SEX RATIO (RURAL)           528 non-null    float64
#  10  AVG HOUSEHOLD SIZE (RURAL)  528 non-null    float64
#  11  POPULATION 1998 (RURAL)     528 non-null    int64
#  12  ANNUAL GROWTH RATE (RURAL)  528 non-null    float64
# ...

# %%
#checking the first rows of the data

# %%
#checking the last rows of the data
df.tail()
# Out:
#      PROVINCE                   DIVISION                   DISTRICT  \
# 523  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 524  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 525  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 526  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 527  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
#
#           SUB DIVISION  AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# 523   SARAROGHA TEHSIL         813.0              98180         51479
# 524    SERWEKAI TEHSIL         398.0              54540         28695
# 525      TIARZA TEHSIL         734.0              45156         23649
# 526  TOI KHULLA TEHSIL         567.0              50413         27462
# 527        WANA TEHSIL        2315.0             153156         81342
#
#      FEMALE (RURAL)  TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  \
# 523           46694                    7             110.25  ...
# ...

# %%
#checking the sample of the data
df.sample(5)
# Out:
#         PROVINCE           DIVISION             DISTRICT       SUB DIVISION  \
# 96        PUNJAB    MULTAN DIVISION      VEHARI DISTRICT      VEHARI TEHSIL
# 371  BALOCHISTAN    Quetta Division  DERA BUGTI DISTRICT  BAIKER SUB-TEHSIL
# 384  BALOCHISTAN    Quetta Division       KOHLU DISTRICT       KOHLU TEHSIL
# 276        SINDH    Sukkur Division      SUKKUR DISTRICT   PANO AQIL TALUKA
# 457          KPK  MALAKAND DIVISION       BUNER DISTRICT       GAGRA TEHSIL
#
#      AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 96         1430.0             783165        397067          386033
# 371         258.0              19497         10583            8914
# 384         231.0              27709         14623           13086
# 276        1042.0             336263        174272          161964
# 457         435.0             269971        134468          135495
#
#      TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# ...

# %%
#checking the statistical summary of the data
df.describe()
# Out:
#        AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# count    528.000000       5.280000e+02  5.280000e+02    5.280000e+02
# mean    1492.005871       2.462780e+05  1.252757e+05    1.209841e+05
# std     2039.453778       2.711898e+05  1.375630e+05    1.337169e+05
# min        0.000000       0.000000e+00  0.000000e+00    0.000000e+00
# 25%      425.000000       5.093450e+04  2.712725e+04    2.397900e+04
# 50%      882.000000       1.652410e+05  8.413450e+04    8.204400e+04
# 75%     1734.250000       3.129112e+05  1.605022e+05    1.522190e+05
# max    18374.000000       2.297375e+06  1.172995e+06    1.124167e+06
#
#        TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# count           528.000000         528.000000                  528.000000
# mean             18.174242          98.982614                    6.277064
# std              25.522248          26.812660                    2.074947
# ...

# %%
#now checking the row which has the maximum area
df.loc[df['AREA (sq.km)'].idxmax()]
# Out:
# PROVINCE                                   PUNJAB
# DIVISION                      BAHAWALPUR DIVISION
# DISTRICT                      BAHAWALPUR DISTRICT
# SUB DIVISION                        YAZMAN TEHSIL
# AREA (sq.km)                              18374.0
# ALL SEXES (RURAL)                          564422
# MALE (RURAL)                               288761
# FEMALE (RURAL)                             275612
# TRANSGENDER (RURAL)                            49
# SEX RATIO (RURAL)                          104.77
# AVG HOUSEHOLD SIZE (RURAL)                   6.41
# POPULATION 1998 (RURAL)                    385770
# ANNUAL GROWTH RATE (RURAL)                   2.02
# ALL SEXES (URBAN)                           48883
# MALE (URBAN)                                24884
# FEMALE (URBAN)                              23995
# TRANSGENDER (URBAN)                             4
# SEX RATIO (URBAN)                           103.7
# AVG HOUSEHOLD SIZE (URBAN)                   6.18
# ...

# %%
#checking the row which has the minimum area
df.loc[df['AREA (sq.km)'].idxmin()]
# Out:
# PROVINCE                                   BALOCHISTAN
# DIVISION                                 Zhob Division
# DISTRICT                      KILLA SAIFULLAH DISTRICT
# SUB DIVISION                         BADINI SUB-TEHSIL
# AREA (sq.km)                                       0.0
# ALL SEXES (RURAL)                                15345
# MALE (RURAL)                                      8720
# FEMALE (RURAL)                                    6625
# TRANSGENDER (RURAL)                                  0
# SEX RATIO (RURAL)                               131.62
# AVG HOUSEHOLD SIZE (RURAL)                        6.89
# POPULATION 1998 (RURAL)                           6583
# ANNUAL GROWTH RATE (RURAL)                        4.55
# ALL SEXES (URBAN)                                    0
# MALE (URBAN)                                         0
# FEMALE (URBAN)                                       0
# TRANSGENDER (URBAN)                                  0
# ...

# %%
# checking the area with maximum transgender population both in rural and urban areas
max_trans_rural = df.loc[df['TRANSGENDER (RURAL)'].idxmax()]
max_trans_urban = df.loc[df['TRANSGENDER (URBAN)'].idxmax()]
print("Max Transgender (Rural):")
print(max_trans_rural)
print("\nMax Transgender (Urban):")
print(max_trans_urban)
# Out:
# Max Transgender (Rural):
# PROVINCE                                    KPK
# DIVISION                      PESHAWAR DIVISION
# DISTRICT                      PESHAWAR DISTRICT
# SUB DIVISION                    PESHAWAR TEHSIL
# AREA (sq.km)                             1257.0
# ALL SEXES (RURAL)                       2297375
# MALE (RURAL)                            1172995
# FEMALE (RURAL)                          1124167
# TRANSGENDER (RURAL)                         213
# SEX RATIO (RURAL)                        104.34
# AVG HOUSEHOLD SIZE (RURAL)                 8.74
# POPULATION 1998 (RURAL)                 1044035
# ANNUAL GROWTH RATE (RURAL)                 4.23
# ALL SEXES (URBAN)                       1969823
# MALE (URBAN)                            1025010
# FEMALE (URBAN)                           944401
# TRANSGENDER (URBAN)                         412
# SEX RATIO (URBAN)                        108.54
# AVG HOUSEHOLD SIZE (URBAN)                 7.97
# ...

# %%
# checking the area with minimum transgender population both in rural and urban areas
min_trans_rural = df.loc[df['TRANSGENDER (RURAL)'].idxmin()]
min_trans_urban = df.loc[df['TRANSGENDER (URBAN)'].idxmin()]
print("Min Transgender (Rural):")
print(min_trans_rural)
print("\nmin Transgender (Urban):")
print(min_trans_urban)
# Out:
# Min Transgender (Rural):
# PROVINCE                                      PUNJAB
# DIVISION                         BAHAWALPUR DIVISION
# DISTRICT                         BAHAWALPUR DISTRICT
# SUB DIVISION                  BAHAWALPUR CITY TEHSIL
# AREA (sq.km)                                  1490.0
# ALL SEXES (RURAL)                                  0
# MALE (RURAL)                                       0
# FEMALE (RURAL)                                     0
# TRANSGENDER (RURAL)                                0
# SEX RATIO (RURAL)                                0.0
# AVG HOUSEHOLD SIZE (RURAL)                       0.0
# POPULATION 1998 (RURAL)                        62916
# ANNUAL GROWTH RATE (RURAL)                       0.0
# ALL SEXES (URBAN)                             682116
# MALE (URBAN)                                  350186
# FEMALE (URBAN)                                331842
# TRANSGENDER (URBAN)                               88
# ...
